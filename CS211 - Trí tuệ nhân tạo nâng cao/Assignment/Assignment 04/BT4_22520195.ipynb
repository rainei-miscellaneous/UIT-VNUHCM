# %% [markdown]
# # Set-up

# %%
# !apt-get update
# !apt install -y python3.8

# %%
# !pip install virtualenv

# %cd /kaggle/working
# !virtualenv venv -p $(which python3.8)
# !virtualenv myenv

# %%
# !git clone https://github.com/GadGadGad/cleanrl
# %cd cleanrl

# %%
# !/kaggle/working/venv/bin/pip install poetry tyro gym[mujoco] moviepy pygame mujoco-py

# %%
# !/kaggle/working/venv/bin/pip install poetry
# !/kaggle/working/venv/bin/poetry install -E mujoco

# %%
# import wandb
# from kaggle_secrets import UserSecretsClient
# user_secrets = UserSecretsClient()
# secret_value_0 = user_secrets.get_secret("WANDB")
# wandb.login(key=secret_value_0)

# %%
# !apt-get update
# !apt-get install -y libegl1-mesa libgles2-mesa libxrandr-dev libxinerama-dev libxi-dev libxcursor-dev

# %%
import os
os.environ["MUJOCO_GL"] = "egl"  # Use EGL for headless rendering

# %% [markdown]
# # Code

# %% [markdown]
# ## DDPG

# %%
# !/kaggle/working/venv/bin/poetry run python /kaggle/working/cleanrl/cleanrl/ddpg_continuous_action.py --env-id HalfCheetah-v4 --capture_video --seed 22520195
# !/kaggle/working/venv/bin/poetry run python /kaggle/working/cleanrl/cleanrl/ddpg_continuous_action.py --env-id HalfCheetah-v4 --capture_video --seed 22520196
# !/kaggle/working/venv/bin/poetry run python /kaggle/working/cleanrl/cleanrl/ddpg_continuous_action.py --env-id HalfCheetah-v4 --capture_video --seed 22520197
# !/kaggle/working/venv/bin/poetry run python /kaggle/working/cleanrl/cleanrl/ddpg_continuous_action.py --env-id HalfCheetah-v4 --capture_video --seed 22520198
# !/kaggle/working/venv/bin/poetry run python /kaggle/working/cleanrl/cleanrl/ddpg_continuous_action.py --env-id HalfCheetah-v4 --capture_video --seed 22520199

# %%
# !/kaggle/working/venv/bin/poetry run python /kaggle/working/cleanrl/cleanrl/ddpg_continuous_action.py --env-id Ant-v4 --capture_video --seed 22520195
# !/kaggle/working/venv/bin/poetry run python /kaggle/working/cleanrl/cleanrl/ddpg_continuous_action.py --env-id Ant-v4 --capture_video --seed 22520196
# !/kaggle/working/venv/bin/poetry run python /kaggle/working/cleanrl/cleanrl/ddpg_continuous_action.py --env-id Ant-v4 --capture_video --seed 22520197
# !/kaggle/working/venv/bin/poetry run python /kaggle/working/cleanrl/cleanrl/ddpg_continuous_action.py --env-id Ant-v4 --capture_video --seed 22520198
# !/kaggle/working/venv/bin/poetry run python /kaggle/working/cleanrl/cleanrl/ddpg_continuous_action.py --env-id Ant-v4 --capture_video --seed 22520199

# %% [markdown]
# ## TD3

# %%
# !/kaggle/working/venv/bin/poetry run python /kaggle/working/cleanrl/cleanrl/td3_continuous_action.py --env-id HalfCheetah-v4 --capture_video --seed 22520195
# !/kaggle/working/venv/bin/poetry run python /kaggle/working/cleanrl/cleanrl/td3_continuous_action.py --env-id HalfCheetah-v4 --capture_video --seed 22520196
# !/kaggle/working/venv/bin/poetry run python /kaggle/working/cleanrl/cleanrl/td3_continuous_action.py --env-id HalfCheetah-v4 --capture_video --seed 22520197
# !/kaggle/working/venv/bin/poetry run python /kaggle/working/cleanrl/cleanrl/td3_continuous_action.py --env-id HalfCheetah-v4 --capture_video --seed 22520198
# !/kaggle/working/venv/bin/poetry run python /kaggle/working/cleanrl/cleanrl/td3_continuous_action.py --env-id HalfCheetah-v4 --capture_video --seed 22520199

# %%
# !/kaggle/working/venv/bin/poetry run python /kaggle/working/cleanrl/cleanrl/td3_continuous_action.py --env-id Ant-v4 --capture_video --seed 22520195
# !/kaggle/working/venv/bin/poetry run python /kaggle/working/cleanrl/cleanrl/td3_continuous_action.py --env-id Ant-v4 --capture_video --seed 22520196
# !/kaggle/working/venv/bin/poetry run python /kaggle/working/cleanrl/cleanrl/td3_continuous_action.py --env-id Ant-v4 --capture_video --seed 22520197
# !/kaggle/working/venv/bin/poetry run python /kaggle/working/cleanrl/cleanrl/td3_continuous_action.py --env-id Ant-v4 --capture_video --seed 22520198
# !/kaggle/working/venv/bin/poetry run python /kaggle/working/cleanrl/cleanrl/td3_continuous_action.py --env-id Ant-v4 --capture_video --seed 22520199
