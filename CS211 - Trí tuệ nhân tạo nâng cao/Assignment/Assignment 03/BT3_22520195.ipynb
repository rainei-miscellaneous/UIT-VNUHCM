# %%
# !git clone https://github.com/ra1nei/cleanrl.git && cd cleanrl

# %% [markdown]
# # Create conda env

# %%
# !conda create -n cleanrl python=3.8 -y > /dev/null 2>&1 && echo "done"

# %%
# !conda info --envs
# !source /opt/conda/bin/activate cleanrl

# %%
import os
os.environ['LD_LIBRARY_PATH'] = '/opt/conda/envs/cleanrl/lib:' + os.environ.get('LD_LIBRARY_PATH', '')
# !echo $LD_LIBRARY_PATH

# %% [markdown]
# # Install necessary packages

# %%
import os
os.chdir('/kaggle/working/cleanrl/requirements')

# %%
# !/opt/conda/envs/cleanrl/bin/pip install -r requirements.txt > /dev/null 2>&1 && echo "done"
# !/opt/conda/envs/cleanrl/bin/pip install -r requirements-atari.txt > /dev/null 2>&1 && echo "done"

# %% [markdown]
# # Run code

# %%
import os
os.chdir('/kaggle/working/cleanrl/cleanrl')

# %% [markdown]
# ## DQL

# %%
# !/opt/conda/envs/cleanrl/bin/python3 dqn.py \
#     --seed 22520195 \
#     --env-id CartPole-v1 \
#     --total-timesteps 1000000 \
#     --capture_video

# %%
# !/opt/conda/envs/cleanrl/bin/python3 dqn_atari.py \
    --seed 22520195 \
    --env-id BreakoutNoFrameskip-v4 \
    --total-timesteps 12000000 \
    --capture_video

# %% [markdown]
# ## DeepDQL

# %%
# !/opt/conda/envs/cleanrl/bin/python3 ddqn.py \
#     --seed 22520195 \
#     --env-id CartPole-v1 \
#     --total-timesteps 1000000 \
#     --capture_video

# %%
# !/opt/conda/envs/cleanrl/bin/python3 ddqn_atari.py \
#     --seed 22520195 \
#     --env-id BreakoutNoFrameskip-v4 \
#     --total-timesteps 5000000 \
#     --capture_video
